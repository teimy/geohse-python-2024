# %% [markdown]
# # **Практическая работа 9: больше графиков и больше численного анализа**
#
# ## **План лекции**
#
# - Обсуждение плана занятия
# - Повторение лекции (рекап по лекционным материалам)
# - Самостоятельная работа + вопросы
#
# Сразу импортируем то, что нам понадобится:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Семинарские задания и домашние задания (6 баллов)

# %% [markdown]
# ### Шляпа какая-то

# %% [markdown]
# (**0.5 балла**) Нарисуйте результат (`shlyapa`) на картинке:

# %%
x = np.arange(-5, 5, 0.1)
y = np.arange(-5, 5, 0.1)


X, Y = np.meshgrid(x, y)
R = np.sqrt(X**2 + Y**2)
shlyapa = np.sin(R)

# Ваш код

# %% [markdown]
# ✨ (**0.25 балла**) Поменяйте код построения фигуры на:
# ```python
# fig = plt.figure(figsize=(12,12))
# ax = plt.axes(projection='3d')
#
# ax.plot_surface(X, Y, shlyapa, cmap='viridis')
# ```

# %%
# Ваш код

# %% [markdown]
# ## Ну и много ли этих ваших экзопланет...
#
# (**0.75 балла**) Откройте файл `data/exoplanets.csv`. В нем находится выборка экзопланет, открытых разными телескопами. Выберите только те, которые открыты [телескопом TESS](https://ru.wikipedia.org/wiki/TESS):

# %%
# Ваш код

# %% [markdown]
# (**0.75 балла**) Какой у них максимальный орбитальный период (`pl_orbper`, дни)? Как называется самая далекая открытая экзопланета (`sy_dist`, парсеки)?

# %%
# Ваш код

# %% [markdown]
# (**0.75 балла**) Выберите только те, которые открыты [телескопом TESS](https://ru.wikipedia.org/wiki/TESS) в 2023-ем году:

# %%
# Ваш код

# %% [markdown]
# ## Как всегда посмотрим на ошибки

# %% [markdown]
# **(0.75 балла)** Что не так с датасетом на картинке? Почему вся картинка почти полностью черная? Что нужно поменять в датасете или визуализации, чтобы картинка отображалась правильно?

# %%
clouds = np.loadtxt('data/clouds.txt')

plt.figure(figsize=(16,9))


plt.pcolormesh(clouds*100, cmap='gray')
cbar = plt.colorbar()
cbar.set_label('Процент облачности', fontsize=20)
cbar.ax.tick_params(labelsize=14) 

plt.gca().tick_params(labelsize=14)
plt.show()

# %% [markdown]
# **(0.75 балла)** Поправьте код в следующей ячейке! Почему все считывается в два столбца?

# %%
users = pd.read_csv('data/example.csv', delimiter=' ')
users
# Out:
#                                   QuotaAmount,StartDate,OwnerName,Username
# 150000,2016-01-01,Chris          Riley,trailhead9.ub20k5i9t8ou@example.com
# 150000,2016-02-01,Chris          Riley,trailhead9.ub20k5i9t8ou@example.com
# 150000,2016-03-01,Chris          Riley,trailhead9.ub20k5i9t8ou@example.com
# 150000,2016-01-01,Harold     Campbell,trailhead14.jibpbwvuy67t@example.com
# 150000,2016-02-01,Harold     Campbell,trailhead14.jibpbwvuy67t@example.com
# 150000,2016-03-01,Harold     Campbell,trailhead14.jibpbwvuy67t@example.com
# 150000,2016-01-01,Jessica     Nichols,trailhead19.d1fxj2goytkp@example.com
# 150000,2016-02-01,Jessica     Nichols,trailhead19.d1fxj2goytkp@example.com
# 150000,2016-03-01,Jessica     Nichols,trailhead19.d1fxj2goytkp@example.com
# 150000,2016-01-01,Catherine     Brown,trailhead16.kojyepokybge@example.com
# 150000,2016-02-01,Catherine     Brown,trailhead16.kojyepokybge@example.com
# ...

# %%
# Ваш код

# %% [markdown]
# ## Как курица лапой
#
# В директории `data/alphabet` лежит куча картинок размера (28,28) с буквами из английского алфавита. Каждая субдиректория называется по имени буквы, в каждой такой субдиректории находятся картинки соответствующей буквы и всякий мусор &ndash; ненужны `txt` файлы и картинки. Вам нужно построить то, как люди в среднем рисуют каждую букву.
#
# С помощью `os.listdir` вы можете получить список в файлов в поддиректории:

# %%
import os

files = os.listdir('data/alphabet/A')
files
# Out:
# ['xfaycsdipw.txt',
#  'A-1679.png',
#  'A-1651.png',
#  'A-1889.png',
#  'A-18.png',
#  'A-1645.png',
#  't1tfmfejgg.png',
#  'ybtev1nmj8.txt',
#  'A-1876.png',
#  'A-1862.png',
#  'A-1692.png',
#  'A-1686.png',
#  'o9cba0jglk.png',
#  'kwhdtn05sk.png',
#  '6vssny6rmr.png',
#  '63x7qv7dqf.png',
#  'yt9yyy8xvq.png',
#  '28mldgtnjk.txt',
#  'w0jow6l1pa.png',
#  '3h64tadhsi.txt',
#  '6i6xwrpjwy.txt',
#  'A-1527.png',
#  'A-1533.png',
#  'z7s6znahu5.txt',
#  'wxvs2o0u6n.png',
#  '3trk4udxu0.txt',
#  'w8p84o53jx.txt',
#  'ohdkwbxvga.png',
#  'A-1719.png',
#  '7ehqqco3k9.png',
#  'ioaa4vnd9r.png',
#  'A-1725.png',
#  'A-1731.png',
#  'A-1902.png',
#  'A-1916.png',
#  'u9daoy3wgk.txt',
#  'd1dy0hfozv.txt',
#  'mo5pf92tjs.png',
#  'A-1917.png',
#  'A-1903.png',
#  '00hjz38blj.png',
#  'A-1730.png',
#  'A-1724.png',
#  'n9h0jyzm0i.png',
#  'A-1718.png',
#  '4eazrtlmmo.png',
#  'A-1532.png',
#  'r00lydq2kd.txt',
#  'A-1526.png',
#  '838sysp47p.txt',
#  '8zaymyyrgr.txt',
#  'qljvh6e0my.png',
# ...

# %% [markdown]
# (**0.25 балл**) Считайте одно изображение с помощью `matplotlib.image.imread` и постройте его на картинке:

# %% [markdown]
# ☝️ Можно развернуть направление оси `y` с помощью `plt.gca().invert_yaxis()`

# %%
from matplotlib.image import imread

# Ваш код

# %% [markdown]
# (**2 балла**) Постройте то, как люди в среднем пишут букву `A`:

# %% [markdown]
# <p>
# <details>
# <summary> ⬇️ <u> Подсказка </u> </summary>
#
# Нужно получить среднее по всем файлам вида `A-цифра.png`. Например, можно сложить все в один массив, а потом разделить на количество файлов.
#
# </details>
# </p>

# %%
# Ваш код

# %% [markdown]
# (**1.5 балл**) Постройте то, как люди в среднем пишут каждую букву алфавита:

# %%
# Ваш код
