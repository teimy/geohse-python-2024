# %% [markdown]
# # **Практическое занятие 4: форматируем строки, читаем файлы, пишем файлы**
#
# ## **План семинара**
#
# - Чего мы хотим добиться сегодня?
# - Тезисно вспоминаем основные понятия с лекции
#     - Вопросы?
# - Подводим итоги семинара

# %% [markdown]
# ### `f`-строки
#
# Добавив к строке до её начала `f` можно вставлять туда переменные, в том числе числовые значения:

# %%
degrees = 24.2
message = f'Сегодня в Москве {degrees} градуса по Цельсию' 

print(message)
# Out:
# Сегодня в Москве 24.2 градуса по Цельсию

# %% [markdown]
# ### Метод `.format()`
#
# Пример использования:

# %%
print('{person1} и {person2}'.format(person1='Биба', person2='Боба'))
# Out:
# Биба и Боба

# %% [markdown]
# # **Работа с файлами в python**
#
# Открываем файл так:

# %%
with open('data/russian_cities.txt') as f:
    russian_cities = f.read()

print(russian_cities) # данные с координатами Российских городов
# Out:
# Moscow 55.7558 37.6178
# SaintPetersburg 59.9500 30.3167
# Novosibirsk 55.0333 82.9167
# Yekaterinburg 56.8356 60.6128
# NizhniyNovgorod 56.3269 44.0075
# Kazan 55.7964 49.1089
# Chelyabinsk 55.1500 61.4000
# Omsk 54.9667 73.3833
# Samara 53.2028 50.1408
# Rostov 47.2333 39.7000
# Ufa 54.7261 55.9475
# Krasnoyarsk 56.0089 92.8719
# Voronezh 51.6717 39.2106
# Perm 58.0139 56.2489
# Volgograd 48.7086 44.5147

# %% [markdown]
# Методы для считывания файлов:
# - `.read()` считывает файл полностью в виде строкиу
# - `.readlines()` считывает все строки и записывает в массив: каждый элемент массива это новая строка
#
# Пример:

# %%
with open('data/russian_cities.txt') as f:
    russian_cities = f.readlines()

print(russian_cities)
# Out:
# ['Moscow 55.7558 37.6178\n', 'SaintPetersburg 59.9500 30.3167\n', 'Novosibirsk 55.0333 82.9167\n', 'Yekaterinburg 56.8356 60.6128\n', 'NizhniyNovgorod 56.3269 44.0075\n', 'Kazan 55.7964 49.1089\n', 'Chelyabinsk 55.1500 61.4000\n', 'Omsk 54.9667 73.3833\n', 'Samara 53.2028 50.1408\n', 'Rostov 47.2333 39.7000\n', 'Ufa 54.7261 55.9475\n', 'Krasnoyarsk 56.0089 92.8719\n', 'Voronezh 51.6717 39.2106\n', 'Perm 58.0139 56.2489\n', 'Volgograd 48.7086 44.5147\n']

# %% [markdown]
# ### Запись в файлы
#
# Почти то же самое, пример:

# %%
with open('data/duplicate_cities.txt', mode='w') as f:
    f.write(russian_cities)

# %cat data/duplicate_cities.txt # лайфхак для вывода (может не работать на Windows)
# Out:
# Moscow 55.7558 37.6178
# SaintPetersburg 59.9500 30.3167
# Novosibirsk 55.0333 82.9167
# Yekaterinburg 56.8356 60.6128
# NizhniyNovgorod 56.3269 44.0075
# Kazan 55.7964 49.1089
# Chelyabinsk 55.1500 61.4000
# Omsk 54.9667 73.3833
# Samara 53.2028 50.1408
# Rostov 47.2333 39.7000
# Ufa 54.7261 55.9475
# Krasnoyarsk 56.0089 92.8719
# Voronezh 51.6717 39.2106
# Perm 58.0139 56.2489
# Volgograd 48.7086 44.5147

# %% [markdown]
# ### Функция `input()`
#
# Функция `input()` позволяет считать данные прямо с клавиатуры и записать их в переменную. Выполните следующую ячейку чтобы попробовать:

# %%
inp = input()
print(f'Мы ввели {inp}')
# Out:
# бла бла бла
# Мы ввели бла бла бла

# %% [markdown]
# # **Задания**
#
# ## Семинарские задания (3 балла)
#
# ### Ну ниче ниче...
#
# **(0.5 балла)** Найдите ошибку в следующем блоке кода:

# %%
singularity = 'Сингулярностью'
message = f'Это переносной модуль с ' singularity ': работа всей моей жизни' 

print(message)
# Out:
#   Cell In[38], line 2
#     message = f'Это переносной модуль с ' singularity ': работа всей моей жизни'
#                                           ^
# SyntaxError: invalid syntax

# %% [markdown]
# **(0.5 балла)**  А что здесь не так с именем файла? Сравните с примером выше!

# %%
with open('data/russian_cities') as f:
    russian_cities = f.readlines()

print(russian_cities)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 with open('data/russian_cities') as f:
#       2     russian_cities = f.readlines()
#       4 print(russian_cities)
#
# File ~/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py:286, in _modified_open(file, *args, **kwargs)
#     279 if file in {0, 1, 2}:
#     280     raise ValueError(
#     281         f"IPython won't let you open fd={file} by default "
#     282         "as it is likely to crash IPython. If you know what you are doing, "
#     283         "you can use builtins' open."
#     284     )
# --> 286 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/russian_cities'

# %% [markdown]
# **(0.25 балла)** Ну и напоследок:

# %%
with open('russian_cities') as f:
    russian_cities = f.readlines()

print(russian_cities)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 with open('russian_cities') as f:
#       2     russian_cities = f.readlines()
#       4 print(russian_cities)
#
# File ~/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py:286, in _modified_open(file, *args, **kwargs)
#     279 if file in {0, 1, 2}:
#     280     raise ValueError(
#     281         f"IPython won't let you open fd={file} by default "
#     282         "as it is likely to crash IPython. If you know what you are doing, "
#     283         "you can use builtins' open."
#     284     )
# --> 286 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'russian_cities'

# %% [markdown]
# ### Запускаем гуся работяги
#
# (**0.5 балла**) Какое-то время в назад в русскоязычном сегменте интернета было популярно спамить [ASCII-изображением](https://ru.wikipedia.org/wiki/%D0%9F%D1%81%D0%B5%D0%B2%D0%B4%D0%BE%D0%B3%D1%80%D0%B0%D1%84%D0%B8%D0%BA%D0%B0) гуся (честно говоря больше похоже на чайку) в [комментарии и трансляции](https://yandex.ru/q/question/otkuda_vzialas_fraza_zapuskaem_gusia_114354b5/). Давайте попробуем поработать с гусем! Считайте гуся в строчку из файла `data/goose.txt` и напечатайте его:

# %%
# Ваш код

# %% [markdown]
# (**0.5 балла**) Используя `python` скопируйте содержимое этого текстового файла в файл в новый файл в директории `data`:

# %%
# Ваш код

# %% [markdown]
# ✨ (**0.5 балла**) Используя метод `.replace()` (найдите сами документацию) замените все символы `░` на пробелы. Выведите получишийся результат в новый файл (из предыдщего пункта)

# %%
# Ваш код

# %% [markdown]
# ### Самые большие пики
#
# **(0.25 балла)** Считайте файл `data/peaks.txt` с названием самых высоких пиков в мире и их относительной высотой (как список строк или как одну большую строку):

# %%
# Ваш код

# %% [markdown]
# **(0.5 балла)** Сделайте из этого файла два списка: название и относительная высота. Это задание можно (но не обязательно) решить сразу несколькими разными способами.

# %%
# Ваш код

# %% [markdown]
# ✨ **(1 балл)** Найдите высоту пять самых высоких пиков (без названия, просто пять значений высоты):

# %%
# Ваш код

# %% [markdown]
# ✨✨ **(1.5 балла)** Найдите название пяти самых высоких пиков. Для этого вам понадобятся [метод `.index()`](https://www.w3schools.com/python/ref_list_index.asp):

# %%
# Ваш код

# %% [markdown]
# ### Задание из независимого экзамена 1
#
# **(2 балла)** Преподаватель хочет определить рейтинг студентов по итогам четырех тестов. Напишите программу, которая поможет преподавателю.
#
# Формат ввода:
# - Вводится информация о каждом студенте в формате '<имя студента>: «оценки за четыре теста через запятую и пробел». Между собой информация о студентах разделена точкой с запятой и пробелом. (**Примечение: считывайте с помощью `input()`**)
# - Гарантируется, что имена студентов не повторяются.
# - Гарантируется, что строка состоит минимум из информации об одном студенте.
#
# Формат вывода:
# - Имена студентов в порядке от меньшего среднего балла к большему.
# - Каждое имя должно выводиться с новой строки.
# - Если средний балл студентов одинаковый, то имена идут в алфавитном порядке.
#
#
# Пример ввода:
#
# `Лиза: 3, 7, 2, 3; Ева-Мария: 2, 8, 9, 2; Ира: 4, 2, 1, 9; Карина: 6, 6, 2, 9`

# %%
# Ваш код

# %% [markdown]
# ### Задание из независимого экзамена 2
#
# **(1 балл)** Функция `get_passwords`, параметрами которой является список строк `passwords` (набор возможных паролей) и целое число `rule` (определяет правило, согласно которому должен быть составлен пароль).
#
#
# Параметр функции `rule` может принимать два возможных значения:
# - 0 (пароль должен состоять только из цифр)
# - 1 (пароль должен состоять только из букв)
#
# Функция должна возвращать список - пароли, которые соответствуют указанному в функции правилу составления.
# Пароли добавляются в список в том же порядке, как и в исходном списке.
#
# Если таких паролей нет, то возвращается пустой список.

# %%
# Ваш код

# %% [markdown]
# ### Дети внимание задание на следующие полчаса прочитать войну и мир
#
# **(0.25 балла)** Считайте файл `war_and_peace.txt` в директории `data` в одну большую строку:

# %%
# Ваш код

# %% [markdown]
# **(0.5 балла)** Найдите первое вхождение имени `Пьер` в этом тексте. Выведите в каком контексте оно первый раз используется:

# %%
# Ваш код

# %% [markdown]
# ✨ **(1.5 балла)** Метод `.find()` ищет только первое вхождение нужный нам подстроки. Найдите все вхождения подстроки `Пьер` в тексте Войны и мира:

# %%
# Ваш код

# %% [markdown]
# ✨✨✨✨ **(без балла)** Используя полученные знания, найдите самое часто встречающееся слово в тексте:

# %%
# Ваш код
