# %% [markdown]
# # **Лекция 2: циклы и списки**
#
# ## **План лекции**
#
# - Организационные вопросы
# - Обсуждение плана лекции и замечания
# - Разбор интересных задач с последнего семинара (если есть желание)
#     - Вопросы?
# - Циклы: `for` и `while`
# - Примеры работы с циклами
#     - Вопросы?
# - Вложенные циклы
# - Ключевые слова в циклах
#     - Вопросы?
# - Списки
# - Индексирование списков
#     - Вопросы?
# - Подведение итогов

# %% [markdown]
# ### Замечания
#
# Не у всех `jupyter notebook` выглядит как у меня + иногда он некрасиво рендерит, например, эмодзи (пример: ☝️). Скорее всего сделать как у меня можно следующим способом:
# 1. Открываем `anaconda navigator`
# 2. Запускаем `cmd.exe promt` (может называться немного по-разному, например еще `conda promt`, подойдет и то и то)
# 3. Пишем туда `conda install -c conda-forge notebook=7.0.6`
# 4. Запускаем заново `jupyter notebook` (может сработать после перезагрузки компьютера)

# %% [markdown]
# # **Циклы**
#
# [Циклы](https://ru.wikipedia.org/wiki/%D0%A6%D0%B8%D0%BA%D0%BB_(%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%80%D0%BE%D0%B2%D0%B0%D0%BD%D0%B8%D0%B5)) позволяют выполнять блок кода несколько раз. Есть два типа циклов:
# - `for`: выполняет блок кода фиксированное количество раз
# - `while`: выполняет блок кода пока не выполнится условие
#
# Давайте посмотрим на пример цикла `for` и на его синтаксис (правила написания):

# %%
for i in range(5):
    print('Это', i, 'раз когда мы выполнили этот блок кода')
# Out:
# Это 0 раз когда мы выполнили этот блок кода
# Это 1 раз когда мы выполнили этот блок кода
# Это 2 раз когда мы выполнили этот блок кода
# Это 3 раз когда мы выполнили этот блок кода
# Это 4 раз когда мы выполнили этот блок кода

# %% [markdown]
# Синтаксис выглядит так:
# ``` python
# for *любое имя переменной* in range(*положительное целое число*):
#     *код который будет повторяться*
#     *код который будет повторяться*
#     *код который будет повторяться*
#     *код который будет повторяться*
# *код который вне цикла*
# ```

# %% [markdown]
# > ☝️ Есть два способа смотреть на цикл `for`:
# > - выполнение блока кода фиксированное количество раз (где переменная `i` является счетчиком *итераций*)
# > - изменение значение переменной `i` фиксированное количество раз

# %% [markdown]
# Посмотрим на цикл `while`:

# %%
i = 0
while i < 5:
    print('Это', i, 'раз когда мы выполнили этот блок кода')
    i = i + 1 # можно написать i += 1
# Out:
# Это 0 раз когда мы выполнили этот блок кода
# Это 1 раз когда мы выполнили этот блок кода
# Это 2 раз когда мы выполнили этот блок кода
# Это 3 раз когда мы выполнили этот блок кода
# Это 4 раз когда мы выполнили этот блок кода

# %% [markdown]
# На практике в 95% случаев используется цикл `for`, но иногда проще понять `while`. Любой цикл можно записать и так и так!

# %% [markdown]
# А что если нам нужно менять переменную `i` с шагом не в `1`, а с каким то другим? Тогда используем вот такую схему:

# %%
for i in range(0, 10, 2):
    print('Переменная i равна ' + str(i) + '. Кстати, это четное число!')
# Out:
# Переменная i равна 0. Кстати, это четное число!
# Переменная i равна 2. Кстати, это четное число!
# Переменная i равна 4. Кстати, это четное число!
# Переменная i равна 6. Кстати, это четное число!
# Переменная i равна 8. Кстати, это четное число!

# %% [markdown]
# Синтаксис выглядит так:
# ``` python
# for *любое имя переменной* range(старт, стоп, шаг):
#     *код который будет повторяться*
# ```
# Первое число в скобках (*аргумент*) это стартовое значение, стоп это последнее значение (не включительно), шаг это... шаг! Кстати, в случае `range(число)` [мы считаем с нуля](https://cseducators.stackexchange.com/questions/5023/why-do-we-count-starting-from-zero)

# %% [markdown]
# Давайте посмотрим на примеры использования циклов. Вспомним задачу про кота Томаса с предыдущего семинара. Теперь мы можем посчитать ее для разного количество выходных:

# %%
for n_holidays in range(10, 80, 10):    
    n_days = 365
    time_holiday = 127 # минуты 
    time_work_day = 63 # минуты
    time_total = n_holidays*time_holiday + time_work_day*(365-n_holidays)
    print('В случае ' + str(n_holidays) + ' выходных в год с котом Томасом будут играть ' + str(time_total) + ' минут')
# Out:
# В случае 10 выходных в год с котом Томасом будут играть 23635 минут
# В случае 20 выходных в год с котом Томасом будут играть 24275 минут
# В случае 30 выходных в год с котом Томасом будут играть 24915 минут
# В случае 40 выходных в год с котом Томасом будут играть 25555 минут
# В случае 50 выходных в год с котом Томасом будут играть 26195 минут
# В случае 60 выходных в год с котом Томасом будут играть 26835 минут
# В случае 70 выходных в год с котом Томасом будут играть 27475 минут

# %% [markdown]
# Можем попробовать использовать цикл `while`, чтобы понять сколько выходных в году оптимально для здоровья кота Томаса:

# %%
time_total = 0       # нужно задать какое-то значение для первой итерации цикла
n_days = 365         # заметим, что переменные лучше задавать вне цикла 
time_holiday = 127
time_work_day = 63
n_holidays = 0
while time_total < 30000:    
    n_holidays = n_holidays + 1
    time_total = (n_holidays)*time_holiday + time_work_day*(365-n_holidays)
print('В случае ' + str(n_holidays) + ' выходных в год с котом Томасом будут играть ' + str(time_total) + ' минут')
# Out:
# В случае 110 выходных в год с котом Томасом будут играть 30035 минут

# %% [markdown]
# ## **Вопросы?**

# %% [markdown]
# ## Вложенные циклы
#
# Ничего нам не мешает сделать и цикл в цикле. Выглядит это вот так:
# ``` python
# for *любое имя переменной* in range(*положительное целое число*):
#     *код который будет повторяться*
#     for *любое (другое) имя переменной* in range(*положительное целое число*):
#         *код который будет повторяться вообще много раз*
# *код который вне цикла*
# ```

# %% [markdown]
# ### Таблица умножения с помощью вложенных циклов
#
# Подумайте, как мы можем сделать таблицу умножения с помощью таких циклов?

# %%
# Здесь мы будем писать код
# Если вы читаете лекцию в jupyter-е не на лекции, то попробуйте написать сами!

# %% [markdown]
# <p>
# <details>
# <summary> ☝ ✨(✨) <u> Красивое решение с отступами </u> </summary>
#
# Это красивое решение, которое формирует красивую табличку с отступами. В нем может быть немного сложно разобраться!
#
# ``` python
# total_str = '    ' # чтобы красиво все вывести запишем все в одну большую текстовую строчку
#
# for i in range(2, 11):
#     total_str += str(i) + ' '
#     if i < 10:
#         total_str += ' ' # это добавка нужна для красивого вывода с пробелами
#                          # попробуйте убрать эти if-ы и посмотрите что получится!
# for i in range(2, 11):
#     total_str += '\n' + str(i) + '  '  # \n - символ перехода на новую строчку
#     if i < 10:
#         total_str += ' '
#     for j in range(2, 11):
#         total_str += str(i*j) + ' '
#         if i*j < 10:
#             total_str += ' ' # это добавка нужна для красивого вывода с пробелами
# print(total_str)
# ```
# </details>
# </p>

# %% [markdown]
# ## Ключевые слова связанные с циклами
#
# Иногда в циклах или условных операторах пригождаются удобные способы пропускать определенные итерации или ничего не делать:
# - `continue` используется если нужно пропустить итерацию цикла
# - `break` используется если нужно выйти из цикла
# - `pass` используется когда ничего делать не надо
#
# Рассмотрим по простому примеру на каждое ключевое слово, начнем с `continue`:

# %%
for i in range(5):
    if i == 3:
        continue
    print(i)
# Out:
# 0
# 1
# 2
# 4

# %% [markdown]
# Как мы видим, мы пропустили итерацию с цифрой `3`. Теперь посмотрим на `break`:

# %%
for i in range(5):
    if i == 3:
        break
    print(i)
# Out:
# 0
# 1
# 2

# %% [markdown]
# Теперь мы просто досрочно вышли из цикла на `3`. И наконец, `pass`:

# %%
for i in range(5):
    if i == 3:
        pass
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# Не произошло вообще ничего!
#
# > ☝ Может показаться, что `pass` не имеет никакого применения: зачем нужно строчка которая не делает вообще ничего? Однако, если вы пишите сложный участок кода, и вам нужно проверить на работоспособность часть кода, однако не писать ничего в одном из условий `if`, то это очень удобный инструмент. Короче говоря, `pass` это такая временная заглушка!

# %% [markdown]
# ## **Вопросы?**

# %% [markdown]
# # **Списки**
#
# *Списки* (`list` или *листы*) это особый тип данных: в нем может храниться сразу несколько переменных. Как и многие вещи в `python`, списки в общем-то очень похожи на списки из реальной жизни. Рассмотрим следующий пример:
#
# Ваня и Руслан (программисты) решили организовать посвящение для первокурсников своего факультета. В гипермаркете им нужно купить:
#
# 0. (Одноразовые) стаканчики
# 1. Мандарины
# 2. Хлеб
# 3. Колбаса
# 4. Сыр
#
# Как бы мы записали список их покупок в `python`?

# %%
print(['Стаканчики', 'Мандарины', 'Хлеб', 'Колбаса', 'Сыр'])
# Out:
# ['Стаканчики', 'Мандарины', 'Хлеб', 'Колбаса', 'Сыр']

# %% [markdown]
# Как вы уже догадались, у нас получился список! *Элементы* списка перечисляются через запятую в квадратных скобках `[` и `]`. Ваня и Руслан записывали элементы списка с номерами: такие номера называются `индексами` списка. С помощью индексов мы можем обращаться к элементам массива:

# %%
checklist = ['Стаканчики', 'Мандарины', 'Хлеб', 'Колбаса', 'Сыр']

print('Вань, во-первых нам надо купить ' + checklist[0])
print('Вань, во-вторых нам надо купить ' + checklist[1])
# Out:
# Вань, во-первых нам надо купить Стаканчики
# Вань, во-вторых нам надо купить Мандарины

# %% [markdown]
# ## Индексирование списков
#
# Списки можно индексировать огромным количеством способов! Мы посмотрим на часть из них.
#
# Во-первых, списки отлично работают вместе с циклами:

# %%
for i in range(5):
    print(str(i) + ' элемент списка: ' + checklist[i])
# Out:
# 0 элемент списка: Стаканчики
# 1 элемент списка: Мандарины
# 2 элемент списка: Хлеб
# 3 элемент списка: Колбаса
# 4 элемент списка: Сыр

# %% [markdown]
# А что если нам не хочется писать циклы, но при этом хочется выбрать только часть элементов массива? Для этого существуют *срезы*:

# %%
print('Элементы от нулевого (включительно) до конечного (невключительно): ', checklist[0:2])  
print('То же самое, если считаем от нуля это можно опустить: ', checklist[:2]) 
print('Элементы от второго до последнего (включительно): ', checklist[2:]) 
print('Элементы от второго до последнего (невключительно): ', checklist[2:-1])
print('-1 это последний элемент списка: ', checklist[-1]) # строго говоря это не срез, а просто элемент
print('Можно считать с конца, -2 это предпоследний: ', checklist[-2]) # строго говоря это не срез, а просто элемент
print('Можно индексировать с шагом: ', checklist[0::2])
# Out:
# Элементы от нулевого (включительно) до конечного (невключительно):  ['Стаканчики', 'Мандарины']
# То же самое, если считаем от нуля это можно опустить:  ['Стаканчики', 'Мандарины']
# Элементы от второго до последнего (включительно):  ['Хлеб', 'Колбаса', 'Сыр']
# Элементы от второго до последнего (невключительно):  ['Хлеб', 'Колбаса']
# -1 это последний элемент списка:  Сыр
# Можно считать с конца, -2 это предпоследний:  Колбаса
# Можно индексировать с шагом:  ['Стаканчики', 'Хлеб', 'Сыр']

# %% [markdown]
# ### Другая форма записи циклов
#
# Важно понимать что мы можем не просто двигаться по списку с помощью счетчика в качестве индекса, но и прямо по самим элементам массива. Это удобно, но мы теряем возможность использовать счетчик:

# %%
for element in checklist:
    print('Элемент списка: ' + element)
# Out:
# Элемент списка: Стаканчики
# Элемент списка: Мандарины
# Элемент списка: Хлеб
# Элемент списка: Колбаса
# Элемент списка: Сыр

# %% [markdown]
# <p>
# <details>
# <summary> ☝ ✨ <u> А как сделать так чтобы счетчик тоже остался? </u> </summary>
#
# Можно использовать вот такую [конструкцию](https://docs.python.org/3/library/functions.html#enumerate):
# ``` python
# for idx, x in enumerate(xs):
#     print(idx, x)
# ```
#
# Справедливости ради, лично мне проще всегда использовать только индексы!
#
# </details>
# </p>

# %% [markdown]
# ### В строчках ведь тоже есть элементы? А их тоже можно индексировать?
#
# Да! Давайте посмотрим:

# %%
sample = 'Здравствуйте. Я, Кирилл. Хотел бы чтобы вы сделали игру, 3Д-экшон суть такова…'
for character in sample:
    print(character)
# Out:
# З
# д
# р
# а
# в
# с
# т
# в
# у
# й
# т
# е
# .
#
# Я
# ,
#
# К
# и
# р
# и
# л
# л
# .
#
# Х
# о
# т
# е
# л
#
# б
# ы
#
# ч
# т
# о
# б
# ы
#
# в
# ы
#
# с
# д
# е
# л
# а
# л
# и
#
# и
# г
# р
# у
# ,
#
# 3
# Д
# -
# э
# к
# ш
# о
# н
#
# с
# у
# т
# ь
#
# т
# а
# к
# о
# в
# а
# …

# %% [markdown]
# Их можно точно так же индексировать:

# %%
print('Как-то раз на одном форуме написали: \n >> ' + sample[:30] + '...') # \n - символ новой строки
# Out:
# Как-то раз на одном форуме написали:
#  >> Здравствуйте. Я, Кирилл. Хотел...

# %% [markdown]
# <p>
# <details>
# <summary>  ☝ ✨✨✨ <u> Особый способ генерировать списки: </u> </summary>
#
#
# В `python` есть особое колдунство, которое называется `list comprehension` (точнее всего переводится на русский как *генератор списков*). Эта вещь позволяет сгенерировать новый список всего в одну строчку. Синтаксис не самый простой, поэтому держитесь:
#
# ``` python
# l = [0, 1, 2, 3, 4, 5, 6, 7]
# new_list = [i**2 for i in l]
# print(new_list) # получается изначальный список, каждый элемент которого возведен в квадрат
#
# ```
#
# Что произошло? Мы взяли каждый элемент (`for i`) листа l (`in l`), и сказали что каждый элемент `new_list` будет равен квадрату (`i**2`). Сложно? Попробуйте сами! Напомню, что вы можете создать новую ячейку тыкнув кнопку `+` наверху.
#
# Впрочем, это далеко не все. В эту конструкцию можно добавить условие `if`:
#
# ``` python
# l = [0, 1, 2, 3, 4, 5, 6, 7]
# new_list = [i**2 for i in l if i%3==0]
# print(new_list) # получается изначальный список, где возвездены в квадрат только элементы делящиеся на три
# ```
#
# Теперь мы вывели список, где возвездены в квадрат только элементы делящиеся на три.
#
# </details>
# </p>

# %% [markdown]
# ## **Вопросы?**
