# %% [markdown]
# # **Лекция 1: осваиваемся с python**
#
# ## **План лекции**
#
# - Как в нашем курсе материалы будут разбиты по сложности?
# - Знакомство с `jupyter notebook` и другими средами разработки
# - Почему `python`?
# - Пишем Hello world
#     - Вопросы?
# - Переменные
# - Операции над переменными
#     - Вопросы?
# - Условные операторы
# - Цепочка операторов `elif` (если успеем)
#     - Вопросы?

# %% [markdown]
# ## **Как будет устроен наш курс?**
#
# - **Курс рассчитан на людей с разным уровнем подготовки: есть более сложные дополнительные материалы и задания:**
#     - ☝️ этим символом обозначены полезные примечания
#     - количеством ✨ *звездочек* ✨ обозначена сложность заданий и комменатриев
#     - ✨: чуть сложнее базового уровня, не очень обязательно
#     - ✨✨: рассчитано на людей с уже имеющимся опытом программирования
#     - ✨✨✨: рассчитано на людей уверенно знающий другой язык
#     - ✨✨✨✨: рассчитано на людей, уже умеющих программировать на питоне
#     - Если вы не программировали до этого, смело игнорируйте все что имеет больше одной звездочки!
# - **Лекционные и семинарские материалы доступны в `jupyter notebook` на [github](https://github.com/teimy/geohse-python-test)**

# %% [markdown]
# ## **Почему `python`?**
#
# `python` &mdash; высокоуровневый язык программирования, который позволяет быстро и просто работать с данными и их визуализировать. Сейчас, он является таким же инструментом ученого, как и, например, телескоп: мало получить данные о звездах или галактиках, нужно еще их обработать и проанализировать. Часто более низкоуровневые языки программирования, такие как `C`, `C++` и `Fortran`, используются для написания библиотек, которые затем используются в питоне. Загрузить данные, поменять форматирование текстового файла, построить график, посчитать статистику, написать отчет &mdash; все это можно сделать в `python`.
# \
# \
# Если вы уже когда-то программировали, то увидите в `python-е` много похожего с другими языками. Если вы никогда не программировали, то `python` &mdash; отличное место для начала.

# %% [markdown]
# ### **Где используется `python`?**
#
# - **Наука, пример для географии/картографии ([GeoPandas](https://github.com/geopandas/geopandas)):** \
#  \
# ![](pictures/1.png)
# - **Анализ данных, разные цели:** \
#  \
# ![](pictures/4.png)
# - **Веб разработка ([Django](https://github.com/smahesh29/Django-WebApp)):** \
#  \
# ![](pictures/2.png)
# - **Минималистичный gamedev/часть софта в gamedev-е ([Пример простой игры](https://www.youtube.com/watch?v=6gLeplbqtqg)):** \
#  \
# ![](pictures/3.png)
# - **Написание простого бота для telegram ([пример](https://www.youtube.com/watch?v=NwBWW8cNCP4)):** \
#  \
# ![](pictures/5.png)
# - **Работа с некоторыми нейросетями, генерация по запросу ([StableDiffusion](https://github.com/Stability-AI/stablediffusion))**:
#  \
# ![](pictures/6.png)

# %% [markdown]
# ## **Знакомство с github**
#
# Github – крупнейший веб сервис для хранения различных проектов, так или иначе связанных с кодом. Там же будут лежать все наши лекционные и семинарские материалы, по этому адресу: https://github.com/teimy/geohse-python-test.
#
# Для нас важно, что это удобное место для размещения и загрузки учебных материалов. Давайте посмотрим как им пользоваться для наших целей. Открываем ссылку, видим перед собой следующее окно:
#
# ![](pictures/10.png)
#
# Нам нужно кликнуть `Download ZIP`. Получится ZIP архив со всеми материалами, его можно распаковать куда-нибудь (желательно в тот путь куда установлена Anaconda).

# %% [markdown]
# <p>
# <details>
# <summary>☝️  ✨✨ <u> Здесь рассказано чуть больше про github и версионный контроль. Кликни на меня! </u>  </summary>
#
# > Github основан на идее версионного контроля: у вас есть директория с вашим проектом, в котором вы постоянно меняете куски кода. Версионный контроль, например самый популярный [git](https://ru.wikipedia.org/wiki/Git), позволяет отслеживать изменения и откатываться к предыдущим версиям. Если вы работаете над проектом в несколько человек или же хотите отправить его в открытый доступ, то обязательно поучитесь использовать версионный контроль. Git это редкий случай, когда есть удобный, хороший и понятный учебник на *русском* языке: [Git SCM](https://git-scm.com/book/ru/v2/)
#
# </details>
# </p>

# %% [markdown]
# ## **Знакомство с `jupyter notebook` и другими средами разработки**
#
# ### Как открыть файл в `jupyter notebook`?
#
# 1. После установки Anaconda у вас должно появиться приложение `Anaconda Navigator`. Запустите его! (может запускаться довольно долго)
# 2. Выберите в меню `jupyter notebook`. Нажмите Launch
# 3. Должно открыть окно в браузере, похожее на это:
#
# ![](pictures/8.png)
#
# 4. ☝️ Если вы установили Anaconda по стандартному пути вы окажетесь в C:\Users\\\*имя юзера\*\. Стоит скопировать рабочие материалы куда-то в эту директорию.
# 5. Перейдите в директорию с рабочими материалами:
#
#
# ![](pictures/9.png)
#
# 6. Кликните на файл `.ipynb`
#
# Теперь давайте разбираться со средой разработки. Мы с вами находимся в `jupyter notebook`. Это смесь кода и текста, которая позволяет писать код, запускать его и сразу видеть результат. Все это происходит в браузере. То, что вы сейчас читаете, это текст, который написан на языке разметки [markdown](https://github.com/adam-p/markdown-here/wiki/Markdown-Cheatsheet). Чтобы запустить код, который написан на `python`, нужно нажать на ячейку и нажать `Ctrl+Enter` или кнопку сверху `Run`. Попробуйте сейчас.

# %%
print('Hello world')
# Out:
# Hello world

# %% [markdown]
# > ☝️ ✨ Где еще можно запускать код на `python`? На самом деле, обычно программисты пишут код в других средах разработки. Для `python` популярными средами разработки являются VScode (советую), PyCharm (не советую), Sublime (пойдет), Atom (пойдет) и Spyder (для науки и численных данных ок).

# %% [markdown]
# <p>
# <details>
# <summary>☝️  ✨✨ <u> Как работают среды разработки и интерпретатор python? Кликни на меня! </u> </summary>
#
# > В целом, можно писать код в текстовом файле и запускать его с помощью специальной программы: часть языков компилируема и для них нужен **компилятор**, а другая часть интепретируемая, и для нужен **интерпретатор**. Python – язык интерпретируемый. В реальности все чуть сложнее, но грубо говоря интепретируемые языки можно выполнять построчно, а в компилируемых у нас должны выделяться начало программы, конец программы и какие-то блоки по середине. Компилируемые языки собираются в исполняемый файл, который уже выдает какой-то результат.
#
# > Не вдаваясь в детали, можно просто ввести в коммандную строку `python test.txt`. Результатом будет выполнение всего кода в этом текстовом файле. Однако, есть более удобный способ работать с кодом: консоль [ipython](https://en.wikipedia.org/wiki/IPython). Это обертка над стандратным интерпретатором, имеющая подсветку синтаксиса и куча других удобных плюсов. Строго говоря, каждая ячейка в `jupyter notebook` является консолью `ipython`!
# </details>
# </p>

# %% [markdown]
# ## **Переменные**
#
# Переменные это одно из центральных понятий в программировании в целом. Почти все программирование состоит из определения переменных (в разном виде) и операций над ними, а все остальное – упрощение работы с этим.
#
#
# В переменных хранятся какие-то значения. Строго говоря, все эти значения хранятся в бинарном коде, но мы работаем в чем-то легко восприимчивом для человека! Раз уж переменные пришли из математики, то начнем с переменных где хранятся численные данные:

# %%
a = 5
b = 3.14
print(a)
print(b)
# Out:
# 5
# 3.14

# %% [markdown]
# > ☝️ *При выполнении ячейки `python` "запоминает" переменные до конца сессии, то есть до перезапуска `jupyter notebook`. Если вы не выполните ячейку сверху, а потом попробуете спросить у питона что-то про эту переменную, он очень удивится и выдаст вам ошибку.*
#
# Некоторые уже это знают, но переменные бывают разных типов. Но здесь мы не задавали напрямую тип переменных! Давайте узнаем какой у нас получился тип переменной:

# %%
type(a), type(b)
# Out:
# (int, float)

# %% [markdown]
# Переменные, в которых хранятся целые числа имеют в большинстве языков типа `integer`, или коротко: `int`. На русском это называется *целочисленной переменной*, однако в языке люди часто говорят просто *интеджер*.
#
#
# Все нецелые числа имеют тип `float` или числа с *плавающей точкой*.
#
# <p>
# <details>
# <summary>☝️  ✨✨ <u> Почему числа с плавающей точкой так называются? Как они работают? </u> </summary>
#
# > В отличие от записи в памяти компьютера целых чисел, которые просто хранятся путем перевода числа из десятичной системы в двоичную, нецелое число так просто не ~проведешь~ переведешь. Ученые, которые создавали языки программирования сильно не мучались, и взяли за основу научную систему записи чисел. Выглядит это так:
# > ![7.png](pictures/7.png)
#
# То есть мы представляем число в виде части где стоит его порядок (10$^n$) (<- видели как здесь можно?) и значимая часть, то есть само значение. Особо проницательные читатели могут догадаться, что это может быть что-то типа разделением логарифмической и линейной шкалы.
# </details>
# </p>

# %% [markdown]
# Переменные позволяют нам общаться с компьютером через язык программирования и называть сложные вещи простой переменной. Переменные могут взаимодействовать друг с другом с помощью **операторов**, например: `+`, `-`, `*`, `/`. Попробуйте сами:

# %%
print('Сумма чисел:', a + b)         # слова после символа '#' - комментарии, они не являются кодом, и нужны для заметок на полях
print('Разность чисел:', a - b)      # операции с нецелыми числами иногда ошибаются на очень малое значение
print('Произведение чисел:', a * b)  # это нормально, и связано с особенностями представления чисел в памяти компьютера
print('Частное чисел:', a / b)
# Out:
# Сумма чисел: 8.14
# Разность чисел: 1.8599999999999999
# Произведение чисел: 15.700000000000001
# Частное чисел: 1.592356687898089

# %% [markdown]
# ### Другие операторы
#
# Есть и другие операторы, котоыре нам могут пригодиться уже в ближайщем будущем. Это математические операторы возведения в степени, [деления нацело и поиска остатка от деления](https://ru.wikipedia.org/wiki/%D0%94%D0%B5%D0%BB%D0%B5%D0%BD%D0%B8%D0%B5_%D1%81_%D0%BE%D1%81%D1%82%D0%B0%D1%82%D0%BA%D0%BE%D0%BC):
#
# - **Дополнительные операторы** :
#     - `x**n` - `x` в степени `n`
#     - `//` - деление нацело
#     - `%` - остаток от деления

# %% [markdown]
# Кроме численных данных, есть и много других типов данных, однако сейчас мы рассмотрим всего несколько. Один из них — это строка. Строка — это набор символов, заключенных в кавычки (или двойные кавычки). Например:

# %%
s = 'Hello world'
print(s)
# Out:
# Hello world

# %% [markdown]
# Строки можно складывать друг с другом:

# %%
h = 'Hello'
w = 'world!'
print(h + ' ' + w)
# Out:
# Hello world!

# %% [markdown]
# Но при этом строки нельзя складывать с числами, иначе получится ошибка:

# %%
print('Температура на улице: ' + 5 + ' градусов по Цельсию')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 print('Температура на улице: ' + 5 + ' градусов по Цельсию')
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# Когда вы будете писать код, вы будете делать много ошибок. Это нормально! Главное &mdash; понимать, что вы делаете не так. К счастью, в этой ошибке уже сказано, что мы делаем не так, давайте посмотрим на сообщение об ошибке:
# ```python
# TypeError: can only concatenate str (not "int") to str
#
# ```
# Если перевести на русский, тут написано: \
# `Ошибка типа: можно складывать только строки (не "int") со строками`
#
#
# Может быть не очень понятно с первого раза, но это нормально. Со временем вы будете понимать ошибки все лучше и лучше. Также вы можете скопировать ошибку и вставить в поисковик, часто там могут подсказать, что не так. Использование поисковика &mdash; это основа программирования, так делают все.
#
#
# Эта ошибка исправляется просто: нужно превратить число в строку. Для этого есть функция `str()`:

# %%
print('Температура на улице: ' + str(5) + ' градусов по Цельсию')
# Out:
# Температура на улице: 5 градусов по Цельсию

# %% [markdown]
# > ☝️ *Напомним, что ошибки делают все, и это нормально! Навык гуглить ошибки и что их вызывало &mdash; один из самых важных навыков у хорошего программиста. Если вы не понимаете, что означает та или иная ошибка, скопируйте её в гугл и посмотрите, что люди пишут на StackOverflow или в другом месте. Результаты будут лучше, если вы будете искать результаты на английском, даже если вы его не очень хорошо знаете!*

# %% [markdown]
# <p>
# <details>
# <summary>☝️  ✨✨✨ <u> Как в python самому создавать ошибки? </u> </summary>
#
# Это делается [довольно просто](https://docs.python.org/3/tutorial/errors.html#raising-exceptions):
# ``` python
# >>> raise NameError('HiThere')
# Traceback (most recent call last):
#   File "<stdin>", line 1, in <module>
# NameError: HiThere
# ```
#
# Насколько я понимаю, классы ошибок нужны чтобы их потом [эффективно отлавливать по категориям](https://docs.python.org/3/tutorial/errors.html#handling-exceptions). Но можно написать туда что угодно!
# </details>
# </p>

# %% [markdown]
# Еще один популярный тип данных это логический тип `bool`. Он может принимать только два значения: `True` и `False` (или 1 и 0). Например:

# %%
T = True
F = False
print(T, F)
print(int(T), int(F))
# Out:
# True False
# 1 0

# %%
type(T)
# Out:
# bool

# %% [markdown]
# ### Логические операторы
#
# - Операторы сравнения (как результат возвращают тип `bool`):
#     -  `>` - больше, `>=` - больше или равно
#     -  `<` - меньше, `<=` - меньше или равно
#     -  `==` - проверка равенства (возрващает два если значение одинаково)
#     -  `!=` - не равно

# %%
print(1 > 0)
# Out:
# True

# %% [markdown]
# С ними работают все стандратные логические операции `and`, `or`, `not`:

# %%
print(T and F) # логическое И
print(T or F)  # логическое ИЛИ
print(not T)   # логическое НЕ
# Out:
# False
# True
# False

# %% [markdown]
# > ☝️ Обратите внимание, что операторы `==` и `=` принципиально отличаются! Первый оператор проверяет, равны или две переменные, а второй &ndash; присваивает значения переменной. Проверяя равенство, используйте только оператор сравнения `==`.

# %% [markdown]
# ## **Условные операторы**
#
# Тип данных `bool` чаще всего используется в условных операторах. Условный оператор позволяет выполнять разные действия в зависимости от условия. Например, если мы хотим написать программу, которая будет выводить на экран число, но только если оно больше `5`, то мы можем использовать условный оператор `if`:

# %%
c > 5
# Out:
# False

# %%
c = 1
d = 5
e = 6

if c > 5:
    print('Переменная c больше пяти. Вот ее значение:', c) # отступы в Python очень важны
                                                           # они определяют, к какому блоку кода 
                                                           # относится команда
# блок кода с условным оператором кончается там, где заканчиваются отступы
if d > 5:
    print('Переменная d больше пяти. Вот ее значение:', d) # в данном случае команда print относится к блоку if
                                                           # и будет выполнена только если d > 5
if e > 5:
    print('Переменная e больше пяти. Вот ее значение:', e)
# Out:
# Переменная e больше пяти. Вот ее значение: 6

# %% [markdown]
# Значение `e > 5` &mdash; это логическое значение `True` или `False`. Если оно равно `True`, то выполняется код внутри `if`, если `False`, то код внутри `if` не выполняется. В нашем случае, `e > 5` равно `True`, поэтому мы видим число `6`. Попробуйте поменять значение в блоке выше `e` на `3` и посмотрите, что будет.

# %% [markdown]
# У условия `if` есть и более расширенный *синтаксис* (правила написания), который позволяет выполнять одно действие, если условие выполняется, и другое, если не выполняется:

# %%
c = 1

if c > 5:
    print('Переменная c больше пяти. Вот ее значение:', c)
else: 
    print('Переменная c меньше или равна пяти. Вот ее значение:', c) # блок кода с условным оператором else
                                                                     # выполняется, если условие в if
                                                                     # сверху не выполнилось
# Out:
# Переменная c меньше или равна пяти. Вот ее значение: 1

# %% [markdown]
# Давайте попробуем совместить наши только что изученные знания об условных операторах и операциях с переменными. Напишем программу, которая будет выводить на экран число только если оно четное:

# %%
number = 5

if *впишите сюда условие*:
    print('Число четное')
else:
    print('Число нечетное')

# %% [markdown]
# Разберем задачку: допустим, нам нужно посчитать бонусные очки в зависимости от количества баллов.
#
# Если баллов:
# 1. От нуля до 100 включительно, то бонусных баллов пять
# 2. Если баллов больше 100, то бонусные баллы составляют 20% от общей суммы баллов
# 3. Если баллов больше 1000, то бонусные баллы составляют 10% от общей суммы баллов
#
# Сначала разберем, что будет если баллов меньше 100:
#
# <p>
# <details>
# <summary> <u> Если баллов меньше или равно 100 </u> </summary>
#
# ``` python
#
# points = 54
# if points <= 100:
#     bonus_points = 5
#
# ```
#
# </details>
# </p>
#
# Теперь если баллов от 100 до 1000:
#
# <p>
# <details>
# <summary> <u> Если баллов больше 100 </u> </summary>
#
# ``` python
#
# points = 1377
# if points > 100:
#     bonus_points = points*0.2
#
# ```
#
# </details>
# </p>
#
# И наконец все вместе:
#
# <p>
# <details>
# <summary> <u> Если баллов произвольное количество </u> </summary>
#
# ``` python
#
# points = 100232
#
# if points <= 100:
#     bonus_points = 5
#
# if points > 100:
#     bonus_points = points*0.2
#
# if points > 1000:
#     bonus_points = points*0.1
#
# print(bonus_points)
#
# ```
#
# </details>
# </p>

# %% [markdown]
# ### ✨ **Цепочка условных операторов `elif`**
#
# Если у нас много разных взаимоисключающих условий, то можно использовать цепочку операторов `elif`. Посмотрим на синтаксис:
#
# ``` python
# if *условие 1*:
#     *код*
# elif *условие 2*:
#     *другой код* # будет выполняться ТОЛЬКО если не выполнилось условие 1
# elif *условие 3*:
#     *очень другой код* # будет выполняться ТОЛЬКО если не выполнились условия 1 и 2
# else:
#     *совсем другой код* # будет выполняться если не выполнились никакие условия
# ```

# %%
number = 4

if number == 1:
    print("один")
elif number == 2:
    print("два")
elif number == 3:
    print("три")
elif number == 4:
    print("четыре")
elif number == 5:
    print("пять")
else: 
    print("много...")
# Out:
# четыре

# %% [markdown]
# ## Анонимная входная анкета
#
# Пожалуйста, заполните [маленькую входную анкету](https://docs.google.com/forms/d/e/1FAIpQLSc-hnzsoGnz7YrK2xT2WHqtD-vMDgBCnh7orT2WeiTXcU69zQ/viewform ). Она нужна для понимания среднего уровня людей!
#
# ![](pictures/poll.png)
